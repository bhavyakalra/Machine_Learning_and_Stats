# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import thinkstats2
import thinkplot

# %%
df = pd.read_csv("data.csv",encoding = 'ISO-8859-1')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.rename(index=str, columns={'InvoiceNo': 'invoice_num',
                              'StockCode' : 'stock_code',
                              'Description' : 'description',
                              'Quantity' : 'quantity',
                              'InvoiceDate' : 'invoice_date',
                              'UnitPrice' : 'unit_price',
                              'CustomerID' : 'cust_id',
                              'Country' : 'country'}, inplace=True)

# %%
df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                  WHITE METAL LANTERN         6
# 2      536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#      invoice_date  unit_price  cust_id         country
# 0  12/1/2010 8:26        2.55  17850.0  United Kingdom
# 1  12/1/2010 8:26        3.39  17850.0  United Kingdom
# 2  12/1/2010 8:26        2.75  17850.0  United Kingdom
# 3  12/1/2010 8:26        3.39  17850.0  United Kingdom
# 4  12/1/2010 8:26        3.39  17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# invoice_num     541909 non-null object
# stock_code      541909 non-null object
# description     540455 non-null object
# quantity        541909 non-null int64
# invoice_date    541909 non-null object
# unit_price      541909 non-null float64
# cust_id         406829 non-null float64
# country         541909 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 37.2+ MB

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# cust_id         135080
# description       1454
# country              0
# unit_price           0
# invoice_date         0
# quantity             0
# stock_code           0
# invoice_num          0
# dtype: int64

# %%
df[df.isnull().any(axis=1)].head()
# Out:
#      invoice_num stock_code                      description  quantity  \
# 622       536414      22139                              NaN        56
# 1443      536544      21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544      21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544      21786               POLKADOT RAIN HAT          4
# 1446      536544      21787            RAIN PONCHO RETROSPOT         2
#
#          invoice_date  unit_price  cust_id         country
# 622   12/1/2010 11:52        0.00      NaN  United Kingdom
# 1443  12/1/2010 14:32        2.51      NaN  United Kingdom
# 1444  12/1/2010 14:32        2.51      NaN  United Kingdom
# 1445  12/1/2010 14:32        0.85      NaN  United Kingdom
# 1446  12/1/2010 14:32        1.66      NaN  United Kingdom

# %%
df['invoice_date'] = pd.to_datetime(df.invoice_date, format='%m/%d/%Y %H:%M')

# %%
df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                  WHITE METAL LANTERN         6
# 2      536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %%
df_new = df.dropna()

# %%
df_new.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                  WHITE METAL LANTERN         6
# 2      536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
# invoice_num     406829 non-null object
# stock_code      406829 non-null object
# description     406829 non-null object
# quantity        406829 non-null int64
# invoice_date    406829 non-null datetime64[ns]
# unit_price      406829 non-null float64
# cust_id         406829 non-null float64
# country         406829 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
df_new.describe().round(2)
# Out:
#         quantity  unit_price    cust_id
# count  406829.00   406829.00  406829.00
# mean       12.06        3.46   15287.69
# std       248.69       69.32    1713.60
# min    -80995.00        0.00   12346.00
# 25%         2.00        1.25   13953.00
# 50%         5.00        1.95   15152.00
# 75%        12.00        3.75   16791.00
# max     80995.00    38970.00   18287.00

# %%
order_canceled = df['invoice_num'].apply(lambda x:int('C' in x))
n1 = order_canceled.sum()
n2 = df.shape[0]
print('Number of orders canceled: {}/{} ({:.2f}%) '.format(n1, n2, n1/n2*100))
# Out:
# Number of orders canceled: 9288/541909 (1.71%)

# %% [markdown]
# # Remove Quantity with negative values

# %%
df_new = df_new[df_new.quantity > 0]

# %%
df_new.describe().round(2)
# Out:
#         quantity  unit_price    cust_id
# count  397924.00   397924.00  397924.00
# mean       13.02        3.12   15294.32
# std       180.42       22.10    1713.17
# min         1.00        0.00   12346.00
# 25%         2.00        1.25   13969.00
# 50%         6.00        1.95   15159.00
# 75%        12.00        3.75   16795.00
# max     80995.00     8142.75   18287.00

# %% [markdown]
# ## Add the column - amount_spent

# %%
df_new['amount_spent'] = df_new['quantity'] * df_new['unit_price']

# %%
# rearrange all the columns for easy reference
df_new = df_new[['invoice_num','invoice_date','stock_code','description','quantity','unit_price','amount_spent','cust_id','country']]

# %% [markdown]
# # Add the columns - Month, Day and Hour for the invoice

# %%
df_new.insert(loc=2, column='year_month', value=df_new['invoice_date'].map(lambda x: 100*x.year + x.month))
df_new.insert(loc=3, column='month', value=df_new.invoice_date.dt.month)
# +1 to make Monday=1.....until Sunday=7
df_new.insert(loc=4, column='day', value=(df_new.invoice_date.dt.dayofweek)+1)
df_new.insert(loc=5, column='hour', value=df_new.invoice_date.dt.hour)

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6        2.55         15.30
# 1                  WHITE METAL LANTERN         6        3.39         20.34
# 2       CREAM CUPID HEARTS COAT HANGER         8        2.75         22.00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6        3.39         20.34
# 4       RED WOOLLY HOTTIE WHITE HEART.         6        3.39         20.34
#
#    cust_id         country
# 0  17850.0  United Kingdom
# 1  17850.0  United Kingdom
# 2  17850.0  United Kingdom
# 3  17850.0  United Kingdom
# 4  17850.0  United Kingdom

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# How many orders made by the customers?

# %%
df_new.groupby(by=['cust_id','country'], as_index=False)['invoice_num'].count().head()
# Out:
#    cust_id         country  invoice_num
# 0  12346.0  United Kingdom            1
# 1  12347.0         Iceland          182
# 2  12348.0         Finland           31
# 3  12349.0           Italy           73
# 4  12350.0          Norway           17

# %%
orders = df_new.groupby(by=['cust_id','country'], as_index=False)['invoice_num'].count()

plt.subplots(figsize=(20,10))
plt.plot(orders.cust_id, orders.invoice_num)
plt.xlabel('Customers ID')
plt.ylabel('Number of Orders')
plt.title('Number of Orders for different Customers')
plt.show()

# %%
orders.invoice_num.max()
# Out:
# 7847

# %% [markdown]
# Check TOP 5 most number of orders

# %%
print('The TOP 5 customers with most number of orders...')
orders.sort_values(by='invoice_num', ascending=False).head()
# Out:
# The TOP 5 customers with most number of orders...
#       cust_id         country  invoice_num
# 4019  17841.0  United Kingdom         7847
# 1888  14911.0            EIRE         5677
# 1298  14096.0  United Kingdom         5111
# 334   12748.0  United Kingdom         4596
# 1670  14606.0  United Kingdom         2700

# %% [markdown]
# How much money spent by the customers

# %%
money_spent = df_new.groupby(by=['cust_id','country'], as_index=False)['amount_spent'].sum()

plt.subplots(figsize=(15,6))
plt.plot(money_spent.cust_id, money_spent.amount_spent)
plt.xlabel('Customers ID')
plt.ylabel('Money spent (Dollar)')
plt.title('Money Spent for different Customers')
plt.show()

# %%
print('The TOP 5 customers with highest money spent...')
money_spent=money_spent.sort_values(by='amount_spent', ascending=False)
money_spent.head()
# Out:
# The TOP 5 customers with highest money spent...
#       cust_id         country  amount_spent
# 1698  14646.0     Netherlands     280206.02
# 4210  18102.0  United Kingdom     259657.30
# 3737  17450.0  United Kingdom     194550.79
# 3017  16446.0  United Kingdom     168472.50
# 1888  14911.0            EIRE     143825.06

# %%
df1=df_new.groupby('invoice_num')['year_month'].unique().value_counts().sort_index()
df1
# Out:
# [201012]    1400
# [201101]     987
# [201102]     998
# [201103]    1321
# [201104]    1149
# [201105]    1555
# [201106]    1393
# [201107]    1331
# [201108]    1281
# [201109]    1756
# [201110]    1929
# [201111]    2658
# [201112]     778
# Name: year_month, dtype: int64

# %%
ax = df1.plot('bar',figsize=(15,6))
ax.set_xlabel('Month',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Months (1st Dec 2010 - 9th Dec 2011)',fontsize=15)
ax.set_xticklabels(('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','Jun_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11','Dec_11'), rotation='horizontal', fontsize=13)
plt.show()

# %% [markdown]
# How many orders (per day)?

# %%
df2=df_new.groupby('invoice_num')['day'].unique().value_counts().sort_index()
df2
# Out:
# [1]    2863
# [2]    3185
# [3]    3455
# [4]    4033
# [5]    2831
# [7]    2169
# Name: day, dtype: int64

# %%
ax = df2.plot('bar',figsize=(15,6))
ax.set_xlabel('Day',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Days',fontsize=15)
ax.set_xticklabels(('Mon','Tue','Wed','Thur','Fri','Sun'), rotation='horizontal', fontsize=15)
plt.show()

# %% [markdown]
# How many orders (per hour)?

# %%
df3=df_new.groupby('invoice_num')['hour'].unique().value_counts().iloc[:-1].sort_index()
df3
# Out:
# [6]        1
# [7]       29
# [8]      555
# [9]     1394
# [10]    2226
# [11]    2276
# [12]    3129
# [13]    2637
# [14]    2275
# [15]    2038
# [16]    1100
# [17]     544
# [18]     169
# [19]     144
# [20]      18
# Name: hour, dtype: int64

# %%
ax = df3.plot('bar',figsize=(15,6))
ax.set_xlabel('Hour',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Hours',fontsize=15)
ax.set_xticklabels(range(6,21), rotation='horizontal', fontsize=15)
plt.show()

# %% [markdown]
# Discover patterns for Unit Price

# %%
df_new.unit_price.describe()
# Out:
# count    397924.000000
# mean          3.116174
# std          22.096788
# min           0.000000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max        8142.750000
# Name: unit_price, dtype: float64

# %%
plt.subplots(figsize=(12,6))
sns.boxplot(df_new.unit_price)
plt.show()

# %%
df_free = df_new[df_new.unit_price == 0]

# %%
df_free.head()
# Out:
#       invoice_num        invoice_date  year_month  month  day  hour  \
# 9302       537197 2010-12-05 14:02:00      201012     12    7    14
# 33576      539263 2010-12-16 14:36:00      201012     12    4    14
# 40089      539722 2010-12-21 13:45:00      201012     12    2    13
# 47068      540372 2011-01-06 16:41:00      201101      1    4    16
# 47070      540372 2011-01-06 16:41:00      201101      1    4    16
#
#       stock_code                   description  quantity  unit_price  \
# 9302       22841  ROUND CAKE TIN VINTAGE GREEN         1         0.0
# 33576      22580  ADVENT CALENDAR GINGHAM SACK         4         0.0
# 40089      22423      REGENCY CAKESTAND 3 TIER        10         0.0
# 47068      22090       PAPER BUNTING RETROSPOT        24         0.0
# 47070      22553        PLASTERS IN TIN SKULLS        24         0.0
#
#        amount_spent  cust_id         country
# 9302            0.0  12647.0         Germany
# 33576           0.0  16560.0  United Kingdom
# 40089           0.0  14911.0            EIRE
# 47068           0.0  13081.0  United Kingdom
# 47070           0.0  13081.0  United Kingdom

# %%
df4=df_free.year_month.value_counts().sort_index()
df4
# Out:
# 201012     3
# 201101     3
# 201102     1
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201108     6
# 201109     2
# 201110     3
# 201111    14
# Name: year_month, dtype: int64

# %%
ax = df4.plot('bar',figsize=(12,6))
ax.set_xlabel('Month',fontsize=15)
ax.set_ylabel('Frequency',fontsize=15)
ax.set_title('Frequency for different Months (Dec 2010 - Dec 2011)',fontsize=15)
ax.set_xticklabels(('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11'), rotation='horizontal', fontsize=13)
plt.show()

# %% [markdown]
# How many orders for each country?

# %%
group_country_orders = df_new.groupby('country')['invoice_num'].count().sort_values()

plt.subplots(figsize=(15,8))
group_country_orders.plot('barh', fontsize=12)
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %%
group_country_orders = df_new.groupby('country')['invoice_num'].count().sort_values()
del group_country_orders['United Kingdom']


plt.subplots(figsize=(15,8))
group_country_orders.plot('barh', fontsize=12, )
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %% [markdown]
# How much money spent by each country?

# %%
group_country_amount_spent = df_new.groupby('country')['amount_spent'].sum().sort_values()
del group_country_amount_spent['United Kingdom']


plt.subplots(figsize=(15,8))
group_country_amount_spent.plot('barh', fontsize=12)
plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()

# %%
from sklearn.utils import resample

# %%
amount_spent=df_new[['amount_spent']]
amount_spent
# Out:
#         amount_spent
# 0              15.30
# 1              20.34
# 2              22.00
# 3              20.34
# 4              20.34
# 5              15.30
# 6              25.50
# 7              11.10
# 8              11.10
# 9              54.08
# 10             12.60
# 11             12.60
# 12             30.00
# 13              9.90
# 14             25.50
# 15             14.85
# 16             19.90
# 17             17.85
# 18             17.85
# 19             31.80
# 20             31.80
# 21             25.50
# 22             14.85
# 23             14.85
# 24             14.85
# 25             17.85
# 26             90.00
# 27             90.00
# 28             45.00
# 29             10.20
# ...              ...
# 541879         30.00
# 541880         15.00
# 541881          8.50
# 541882         10.08
# 541883         10.50
# 541884         15.00
# 541885         10.20
# 541886          4.68
# 541887         15.00
# 541888         11.40
# 541889         23.40
# 541890         23.60
# 541891         30.00
# 541892        214.80
# 541893         70.80
# 541894         23.40
# 541895         19.80
# 541896         19.80
# 541897         15.00
# 541898         15.00
# 541899         15.00
# 541900         15.00
# 541901         15.60
# 541902         23.40
# 541903         16.60
# 541904         10.20
# 541905         12.60
# 541906         16.60
# 541907         16.60
# 541908         14.85
#
# [397924 rows x 1 columns]

# %%
means = []

i=0

#confidence interval shrinks with more samples
while i<1000:
    means.append(resample(amount_spent, replace=True, n_samples=len(amount_spent)).mean())
    i+=1

# %%
df_means = pd.DataFrame(means)

# %%
df_means
# Out:
#      amount_spent
# 0       22.780478
# 1       22.018002
# 2       23.096855
# 3       22.942006
# 4       22.178763
# 5       22.793850
# 6       23.264910
# 7       22.088248
# 8       22.661260
# 9       22.026864
# 10      21.819116
# 11      21.996083
# 12      22.183128
# 13      21.907355
# 14      22.882495
# 15      22.242110
# 16      22.671351
# 17      21.858146
# 18      22.183025
# 19      22.040945
# 20      23.037394
# 21      22.638867
# 22      22.657833
# 23      22.334132
# 24      21.934691
# 25      22.929347
# 26      22.627476
# 27      22.850392
# 28      21.815851
# 29      23.022635
# ..            ...
# 970     22.184220
# 971     21.925806
# 972     22.566767
# 973     23.311339
# 974     22.521559
# 975     22.782934
# 976     21.758911
# 977     22.439427
# 978     22.266254
# 979     23.583586
# 980     22.676628
# 981     22.221067
# 982     22.492384
# 983     21.566465
# 984     23.114616
# 985     22.041763
# 986     22.100716
# 987     22.790656
# 988     22.016208
# 989     23.112078
# 990     22.325203
# 991     22.211089
# 992     21.711144
# 993     22.684119
# 994     22.774215
# 995     22.436116
# 996     22.581575
# 997     23.045173
# 998     22.693892
# 999     22.896156
#
# [1000 rows x 1 columns]

# %%
df_means.plot.box()

# %%
confidence_interval = df_means.quantile([0.05 - 0.025, 0.95 + 0.025])

# %%
confidence_interval
# Out:
#        amount_spent
# 0.025     21.639148
# 0.975     23.471725

# %%
lower_interval = confidence_interval.iloc[0,0]
upper_interval = confidence_interval.iloc[1,0]

print(lower_interval, upper_interval)
# Out:
# 21.639148370491036 23.471724859528376

# %%
amount_spent.mean()
# Out:
# amount_spent    22.394749
# dtype: float64

# %%
if amount_spent.mean().iloc[0] >= lower_interval and amount_spent.mean().iloc[0] <= upper_interval:
    print('The true mean {} is between the confidence interval of {} and {}'.format(amount_spent.mean().iloc[0], confidence_interval.iloc[0,0], confidence_interval.iloc[1,0]))
# Out:
# The true mean 22.39474850474768 is between the confidence interval of 21.639148370491036 and 23.471724859528376

# %%
fig, ax = plt.subplots(figsize=(18,10)) # figsize in inches
sns.distplot(df_means, rug=True)
#sns.boxplot(data=df_means, orient="h", notch=True)

#wierd
x1 = [lower_interval, upper_interval]
x2 = [0.0, 0.0]    

ax.plot(x1, x2, 'red', linestyle='--', marker='o', lw=3)


y1 = [amount_spent.mean().iloc[0], amount_spent.mean().iloc[0]]
y2 = [0.0, 0.0]


ax.plot(y1, y2, 'green', linestyle='--', marker='o', lw=3)
# Out:
# C:\Users\Aarushi\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# How many means are within the confidence interval?

# %%
df_means['isInInterval'] = df_means['amount_spent'].apply(lambda x : x >= lower_interval and x <= upper_interval)

# %%
df_means
# Out:
#      amount_spent  isInInterval
# 0       22.780478          True
# 1       22.018002          True
# 2       23.096855          True
# 3       22.942006          True
# 4       22.178763          True
# 5       22.793850          True
# 6       23.264910          True
# 7       22.088248          True
# 8       22.661260          True
# 9       22.026864          True
# 10      21.819116          True
# 11      21.996083          True
# 12      22.183128          True
# 13      21.907355          True
# 14      22.882495          True
# 15      22.242110          True
# 16      22.671351          True
# 17      21.858146          True
# 18      22.183025          True
# 19      22.040945          True
# 20      23.037394          True
# 21      22.638867          True
# 22      22.657833          True
# 23      22.334132          True
# 24      21.934691          True
# 25      22.929347          True
# 26      22.627476          True
# 27      22.850392          True
# 28      21.815851          True
# 29      23.022635          True
# ..            ...           ...
# 970     22.184220          True
# 971     21.925806          True
# 972     22.566767          True
# 973     23.311339          True
# 974     22.521559          True
# 975     22.782934          True
# 976     21.758911          True
# 977     22.439427          True
# 978     22.266254          True
# 979     23.583586         False
# 980     22.676628          True
# 981     22.221067          True
# 982     22.492384          True
# 983     21.566465         False
# 984     23.114616          True
# 985     22.041763          True
# 986     22.100716          True
# 987     22.790656          True
# 988     22.016208          True
# 989     23.112078          True
# 990     22.325203          True
# 991     22.211089          True
# 992     21.711144          True
# 993     22.684119          True
# 994     22.774215          True
# 995     22.436116          True
# 996     22.581575          True
# 997     23.045173          True
# 998     22.693892          True
# 999     22.896156          True
#
# [1000 rows x 2 columns]

# %%
(sum(df_means['isInInterval']) / len(df_means))*100
# Out:
# 95.0

# %%
def amount(param):
    if param <=21:
        return 'less'
    elif param >21 and param <=23:
        return 'adequate'
    elif param >23:
        return 'more'
    
df_new['money_spent'] = df_new['amount_spent'].apply(amount)

# %%
df_new
# Out:
#        invoice_num        invoice_date  year_month  month  day  hour  \
# 0           536365 2010-12-01 08:26:00      201012     12    3     8
# 1           536365 2010-12-01 08:26:00      201012     12    3     8
# 2           536365 2010-12-01 08:26:00      201012     12    3     8
# 3           536365 2010-12-01 08:26:00      201012     12    3     8
# 4           536365 2010-12-01 08:26:00      201012     12    3     8
# 5           536365 2010-12-01 08:26:00      201012     12    3     8
# 6           536365 2010-12-01 08:26:00      201012     12    3     8
# 7           536366 2010-12-01 08:28:00      201012     12    3     8
# 8           536366 2010-12-01 08:28:00      201012     12    3     8
# 9           536367 2010-12-01 08:34:00      201012     12    3     8
# 10          536367 2010-12-01 08:34:00      201012     12    3     8
# 11          536367 2010-12-01 08:34:00      201012     12    3     8
# 12          536367 2010-12-01 08:34:00      201012     12    3     8
# 13          536367 2010-12-01 08:34:00      201012     12    3     8
# 14          536367 2010-12-01 08:34:00      201012     12    3     8
# 15          536367 2010-12-01 08:34:00      201012     12    3     8
# 16          536367 2010-12-01 08:34:00      201012     12    3     8
# 17          536367 2010-12-01 08:34:00      201012     12    3     8
# 18          536367 2010-12-01 08:34:00      201012     12    3     8
# 19          536367 2010-12-01 08:34:00      201012     12    3     8
# 20          536367 2010-12-01 08:34:00      201012     12    3     8
# 21          536368 2010-12-01 08:34:00      201012     12    3     8
# 22          536368 2010-12-01 08:34:00      201012     12    3     8
# 23          536368 2010-12-01 08:34:00      201012     12    3     8
# 24          536368 2010-12-01 08:34:00      201012     12    3     8
# 25          536369 2010-12-01 08:35:00      201012     12    3     8
# 26          536370 2010-12-01 08:45:00      201012     12    3     8
# 27          536370 2010-12-01 08:45:00      201012     12    3     8
# 28          536370 2010-12-01 08:45:00      201012     12    3     8
# 29          536370 2010-12-01 08:45:00      201012     12    3     8
# ...            ...                 ...         ...    ...  ...   ...
# 541879      581585 2011-12-09 12:31:00      201112     12    5    12
# 541880      581585 2011-12-09 12:31:00      201112     12    5    12
# 541881      581585 2011-12-09 12:31:00      201112     12    5    12
# 541882      581585 2011-12-09 12:31:00      201112     12    5    12
# 541883      581585 2011-12-09 12:31:00      201112     12    5    12
# 541884      581585 2011-12-09 12:31:00      201112     12    5    12
# 541885      581585 2011-12-09 12:31:00      201112     12    5    12
# 541886      581585 2011-12-09 12:31:00      201112     12    5    12
# 541887      581585 2011-12-09 12:31:00      201112     12    5    12
# 541888      581585 2011-12-09 12:31:00      201112     12    5    12
# 541889      581585 2011-12-09 12:31:00      201112     12    5    12
# 541890      581586 2011-12-09 12:49:00      201112     12    5    12
# 541891      581586 2011-12-09 12:49:00      201112     12    5    12
# 541892      581586 2011-12-09 12:49:00      201112     12    5    12
# 541893      581586 2011-12-09 12:49:00      201112     12    5    12
# 541894      581587 2011-12-09 12:50:00      201112     12    5    12
# 541895      581587 2011-12-09 12:50:00      201112     12    5    12
# 541896      581587 2011-12-09 12:50:00      201112     12    5    12
# 541897      581587 2011-12-09 12:50:00      201112     12    5    12
# 541898      581587 2011-12-09 12:50:00      201112     12    5    12
# 541899      581587 2011-12-09 12:50:00      201112     12    5    12
# 541900      581587 2011-12-09 12:50:00      201112     12    5    12
# 541901      581587 2011-12-09 12:50:00      201112     12    5    12
# 541902      581587 2011-12-09 12:50:00      201112     12    5    12
# 541903      581587 2011-12-09 12:50:00      201112     12    5    12
# 541904      581587 2011-12-09 12:50:00      201112     12    5    12
# 541905      581587 2011-12-09 12:50:00      201112     12    5    12
# 541906      581587 2011-12-09 12:50:00      201112     12    5    12
# 541907      581587 2011-12-09 12:50:00      201112     12    5    12
# 541908      581587 2011-12-09 12:50:00      201112     12    5    12
#
#        stock_code                          description  quantity  unit_price  \
# 0          85123A   WHITE HANGING HEART T-LIGHT HOLDER         6        2.55
# 1           71053                  WHITE METAL LANTERN         6        3.39
# 2          84406B       CREAM CUPID HEARTS COAT HANGER         8        2.75
# 3          84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6        3.39
# 4          84029E       RED WOOLLY HOTTIE WHITE HEART.         6        3.39
# 5           22752         SET 7 BABUSHKA NESTING BOXES         2        7.65
# 6           21730    GLASS STAR FROSTED T-LIGHT HOLDER         6        4.25
# 7           22633               HAND WARMER UNION JACK         6        1.85
# 8           22632            HAND WARMER RED POLKA DOT         6        1.85
# 9           84879        ASSORTED COLOUR BIRD ORNAMENT        32        1.69
# 10          22745           POPPY'S PLAYHOUSE BEDROOM          6        2.10
# 11          22748            POPPY'S PLAYHOUSE KITCHEN         6        2.10
# 12          22749    FELTCRAFT PRINCESS CHARLOTTE DOLL         8        3.75
# 13          22310              IVORY KNITTED MUG COSY          6        1.65
# 14          84969   BOX OF 6 ASSORTED COLOUR TEASPOONS         6        4.25
# 15          22623        BOX OF VINTAGE JIGSAW BLOCKS          3        4.95
# 16          22622       BOX OF VINTAGE ALPHABET BLOCKS         2        9.95
# 17          21754             HOME BUILDING BLOCK WORD         3        5.95
# 18          21755             LOVE BUILDING BLOCK WORD         3        5.95
# 19          21777          RECIPE BOX WITH METAL HEART         4        7.95
# 20          48187                  DOORMAT NEW ENGLAND         4        7.95
# 21          22960             JAM MAKING SET WITH JARS         6        4.25
# 22          22913          RED COAT RACK PARIS FASHION         3        4.95
# 23          22912       YELLOW COAT RACK PARIS FASHION         3        4.95
# 24          22914         BLUE COAT RACK PARIS FASHION         3        4.95
# 25          21756             BATH BUILDING BLOCK WORD         3        5.95
# 26          22728            ALARM CLOCK BAKELIKE PINK        24        3.75
# 27          22727            ALARM CLOCK BAKELIKE RED         24        3.75
# 28          22726           ALARM CLOCK BAKELIKE GREEN        12        3.75
# 29          21724      PANDA AND BUNNIES STICKER SHEET        12        0.85
# ...           ...                                  ...       ...         ...
# 541879      22726           ALARM CLOCK BAKELIKE GREEN         8        3.75
# 541880      22727            ALARM CLOCK BAKELIKE RED          4        3.75
# 541881      16016          LARGE CHINESE STYLE SCISSOR        10        0.85
# 541882      21916      SET 12 RETRO WHITE CHALK STICKS        24        0.42
# 541883      84692          BOX OF 24 COCKTAIL PARASOLS        25        0.42
# 541884      84946         ANTIQUE SILVER T-LIGHT GLASS        12        1.25
# 541885      21684     SMALL MEDINA STAMPED METAL BOWL         12        0.85
# 541886      22398           MAGNETS PACK OF 4 SWALLOWS        12        0.39
# 541887      23328   SET 6 SCHOOL MILK BOTTLES IN CRATE         4        3.75
# 541888      23145       ZINC T-LIGHT HOLDER STAR LARGE        12        0.95
# 541889      22466       FAIRY TALE COTTAGE NIGHT LIGHT        12        1.95
# 541890      22061  LARGE CAKE STAND  HANGING STRAWBERY         8        2.95
# 541891      23275     SET OF 3 HANGING OWLS OLLIE BEAK        24        1.25
# 541892      21217        RED RETROSPOT ROUND CAKE TINS        24        8.95
# 541893      20685                DOORMAT RED RETROSPOT        10        7.08
# 541894      22631             CIRCUS PARADE LUNCH BOX         12        1.95
# 541895      22556       PLASTERS IN TIN CIRCUS PARADE         12        1.65
# 541896      22555            PLASTERS IN TIN STRONGMAN        12        1.65
# 541897      22728            ALARM CLOCK BAKELIKE PINK         4        3.75
# 541898      22727            ALARM CLOCK BAKELIKE RED          4        3.75
# 541899      22726           ALARM CLOCK BAKELIKE GREEN         4        3.75
# 541900      22730           ALARM CLOCK BAKELIKE IVORY         4        3.75
# 541901      22367      CHILDRENS APRON SPACEBOY DESIGN         8        1.95
# 541902      22629                  SPACEBOY LUNCH BOX         12        1.95
# 541903      23256          CHILDRENS CUTLERY SPACEBOY          4        4.15
# 541904      22613          PACK OF 20 SPACEBOY NAPKINS        12        0.85
# 541905      22899         CHILDREN'S APRON DOLLY GIRL          6        2.10
# 541906      23254        CHILDRENS CUTLERY DOLLY GIRL          4        4.15
# 541907      23255      CHILDRENS CUTLERY CIRCUS PARADE         4        4.15
# 541908      22138        BAKING SET 9 PIECE RETROSPOT          3        4.95
#
#         amount_spent  cust_id         country money_spent
# 0              15.30  17850.0  United Kingdom        less
# 1              20.34  17850.0  United Kingdom        less
# 2              22.00  17850.0  United Kingdom    adequate
# 3              20.34  17850.0  United Kingdom        less
# 4              20.34  17850.0  United Kingdom        less
# 5              15.30  17850.0  United Kingdom        less
# 6              25.50  17850.0  United Kingdom        more
# 7              11.10  17850.0  United Kingdom        less
# 8              11.10  17850.0  United Kingdom        less
# 9              54.08  13047.0  United Kingdom        more
# 10             12.60  13047.0  United Kingdom        less
# 11             12.60  13047.0  United Kingdom        less
# 12             30.00  13047.0  United Kingdom        more
# 13              9.90  13047.0  United Kingdom        less
# 14             25.50  13047.0  United Kingdom        more
# 15             14.85  13047.0  United Kingdom        less
# 16             19.90  13047.0  United Kingdom        less
# 17             17.85  13047.0  United Kingdom        less
# 18             17.85  13047.0  United Kingdom        less
# 19             31.80  13047.0  United Kingdom        more
# 20             31.80  13047.0  United Kingdom        more
# 21             25.50  13047.0  United Kingdom        more
# 22             14.85  13047.0  United Kingdom        less
# 23             14.85  13047.0  United Kingdom        less
# 24             14.85  13047.0  United Kingdom        less
# 25             17.85  13047.0  United Kingdom        less
# 26             90.00  12583.0          France        more
# 27             90.00  12583.0          France        more
# 28             45.00  12583.0          France        more
# 29             10.20  12583.0          France        less
# ...              ...      ...             ...         ...
# 541879         30.00  15804.0  United Kingdom        more
# 541880         15.00  15804.0  United Kingdom        less
# 541881          8.50  15804.0  United Kingdom        less
# 541882         10.08  15804.0  United Kingdom        less
# 541883         10.50  15804.0  United Kingdom        less
# 541884         15.00  15804.0  United Kingdom        less
# 541885         10.20  15804.0  United Kingdom        less
# 541886          4.68  15804.0  United Kingdom        less
# 541887         15.00  15804.0  United Kingdom        less
# 541888         11.40  15804.0  United Kingdom        less
# 541889         23.40  15804.0  United Kingdom        more
# 541890         23.60  13113.0  United Kingdom        more
# 541891         30.00  13113.0  United Kingdom        more
# 541892        214.80  13113.0  United Kingdom        more
# 541893         70.80  13113.0  United Kingdom        more
# 541894         23.40  12680.0          France        more
# 541895         19.80  12680.0          France        less
# 541896         19.80  12680.0          France        less
# 541897         15.00  12680.0          France        less
# 541898         15.00  12680.0          France        less
# 541899         15.00  12680.0          France        less
# 541900         15.00  12680.0          France        less
# 541901         15.60  12680.0          France        less
# 541902         23.40  12680.0          France        more
# 541903         16.60  12680.0          France        less
# 541904         10.20  12680.0          France        less
# 541905         12.60  12680.0          France        less
# 541906         16.60  12680.0          France        less
# 541907         16.60  12680.0          France        less
# 541908         14.85  12680.0          France        less
#
# [397924 rows x 14 columns]

# %%
df1=df_new[['amount_spent','money_spent']]
df1.head()
# Out:
#    amount_spent money_spent
# 0         15.30        less
# 1         20.34        less
# 2         22.00    adequate
# 3         20.34        less
# 4         20.34        less

# %%
count = df1.groupby(['money_spent']).count()

# %%
count
# Out:
#              amount_spent
# money_spent
# adequate             2676
# less               322336
# more                72912

# %%
contingency_table=pd.crosstab(df_new[df_new['country']=='United Kingdom']['country'],df_new["money_spent"])
print('contingency_table :-\n',contingency_table)
# Out:
# contingency_table :-
#  money_spent     adequate    less   more
# country
# United Kingdom      2320  293384  58641

# %%
contingency_table=pd.crosstab(df_new['country'],df_new["money_spent"])
print('contingency_table :-\n',contingency_table.head(3))
# Out:
# contingency_table :-
#  money_spent  adequate  less  more
# country
# Australia           3   371   811
# Austria             2   297    99
# Bahrain             0     8     9

# %%
Observed_Values = contingency_table.head(3).values 
print("Observed Values :-\n",Observed_Values)
# Out:
# Observed Values :-
#  [[  3 371 811]
#  [  2 297  99]
#  [  0   8   9]]

# %%
import scipy.stats
b=scipy.stats.chi2_contingency(contingency_table.head(3))
Expected_Values = b[3]
print("Expected Values :-\n",Expected_Values)
# Out:
# Expected Values :-
#  [[3.70312500e+00 5.00662500e+02 6.80634375e+02]
#  [1.24375000e+00 1.68155000e+02 2.28601250e+02]
#  [5.31250000e-02 7.18250000e+00 9.76437500e+00]]

# %%
no_of_rows=len(contingency_table.iloc[0:3,0])
no_of_columns=len(contingency_table.iloc[0,0:3])
degree=(no_of_rows-1)*(no_of_columns-1)
print("Degree of Freedom:-",df)
# Out:
# Degree of Freedom:- 4

# %%
#Significance Level 5%
alpha=0.05

# %%
from scipy.stats import chi2
chi_square=sum([(o-e)**2./e for o,e in zip(Observed_Values,Expected_Values)])
chi_square_statistic=chi_square[0]+chi_square[1]
print("chi-square statistic:-",chi_square_statistic)
# Out:
# chi-square statistic:- 133.04433414817888

# %%
critical_value=chi2.ppf(q=1-alpha,df=df)
print('critical_value:',critical_value)
# Out:
# critical_value: 9.487729036781154

# %%
p_value=1-chi2.cdf(x=chi_square_statistic,df=degree)
print('p-value:',p_value)
# Out:
# p-value: 0.0

# %%
print('Significance level: ',alpha)
print('Degree of Freedom: ',df)
print('chi-square statistic:',chi_square_statistic)
print('critical_value:',critical_value)
print('p-value:',p_value)
# Out:
# Significance level:  0.05
# Degree of Freedom:  4
# chi-square statistic: 133.04433414817888
# critical_value: 9.487729036781154
# p-value: 0.0

# %%
if chi_square_statistic>=critical_value:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
    
if p_value<=alpha:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
# Out:
# Reject H0,There is a relationship between 2 categorical variables
# Reject H0,There is a relationship between 2 categorical variables

# %%
df_spent=df_new['amount_spent']
mean,std=df_spent.mean(),df_spent.std()
mean, std
# Out:
# (22.39474850474768, 309.05558838012377)

# %%
print("Skewness: %f" % df_new['amount_spent'].skew())
# Out:
# Skewness: 451.465538

# %%
pdf = thinkstats2.NormalPdf(mean, std)
thinkplot.Pdf(pdf, label='normal')
thinkplot.Config(xlabel='amount_spent', ylabel='PDF')

# %%
pmf = pdf.MakePmf()

# %%
cdf = thinkstats2.Cdf(df_spent, label='CDF x')
thinkplot.Cdf(cdf)
thinkplot.Config(xlabel='Amount', ylabel='CDF', loc='lower right')

# %%
hist = thinkstats2.Hist(pmf, label='amount')
thinkplot.Hist(hist)
thinkplot.Config(xlabel='Amount', ylabeal='Count')

# %%
sns.heatmap(df_new.corr(),square=True,annot=True,fmt='.1f')

# %%
sns.pairplot(data=df_new[['quantity', 'amount_spent', 'unit_price']])
